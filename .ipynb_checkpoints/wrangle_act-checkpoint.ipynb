# %% [markdown]
# # : Introduction:
# "WeRateDogs" is a project that is focused on how to collect data from different sources, assessing the collected data and cleaning it to make it easier for analysis and visualization process. "WE_RATE_DOGS" generally provide insight into how people react to posts on twetter of different dog breeds, other dog aspects aspects included are dog names and dog stages.
#
# # : Define questions and goals.
#
# ## a) Goals.
# The goal of this project is to wrangle "WeRateDogs" Twitter data and create interesting and trustworthy analyses and visualizations.
# Some of the questions that will help us do the analysis and visualitions are listed below.
#
# ## b) Define the questions.
# 1. What type of dog stage receive most likes (favorite_count) when posted.?
# 2. Which dog stage received the most retweet?
# 3. Which dog stages is the most popularly posted?
# 4. Identify dog breeds with the highest numerator ratings?
# 5. Which dog breeds are the most retweeted?
# 6. Determine the most popular breeds of dogs posted?
# 7. Determine the top popular dog names from the data?
# 8. Which dog breeds received most likes (favorite_count)?
# 9. Determine the most popular dog names posted from the data?
# 10. Which dog breeds received most likes (favorite_count)?
# 11. What is the relationship between favorite_count and retweet_count?
#
#
# ## c) Determine the libs and import.
# After understing what is required in the project, Determine the libraries required for the execution of tasks in the project and import them, since we will be using them through out our nalysis proces.

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
#import the libraries to be used.
import pandas as pd
# %matplotlib inline
import numpy as np
import requests
from matplotlib import pyplot as plt
from matplotlib import rcParams as rP
import seaborn as sns
import os
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# %% [markdown]
# # : Data Wrangling.
# Data wrangling is the process of acquiring data from different sources and making it more valuable and appropriate for analysis and visualizations through assessing and cleaning.

# %% [markdown]
# ## a) Gathering the data
# This is the process of collecting data and using pandas to read it into the dataframe.

# %% [markdown]
# ### Read the `twitter-archive-enhanced.csv` data

# %%
# Read CSV (comma-separated) file into DataFrame usind pandas
twitter_archive_df = pd.read_csv('twitter-archive-enhanced.csv')

# %%
folder_name = ('image_predictions.tsv')
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
with open(os.path.join(folder_name, url.split('/')[-1]), mode='wb') as file:
    file.write(response.content)

# %%
#check the content of the folder downloaded to ensure success
os.listdir(folder_name)
# Out:
# ['image-predictions.tsv']

# %% [markdown]
# ### Read the `image-predictions.tsv` data

# %%
# Read CSV (comma-separated) file into DataFrame usind pandas
image_predictions_df = pd.read_csv('image-predictions.tsv', sep='\t')

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### Read the `tweets_df` data

# %%
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_archive_df.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()

# %%
#Creating an empty list
tweets_list = []
with open('tweet-json.txt', 'r') as file:
  for line in file:
    data = json.loads(line)
    tweets_list.append(data)
tweets_df = pd.DataFrame(tweets_list, columns=['id', 'retweet_count', 'favorite_count'])

# %%
#Listing the 3 datasets collected.
tweets_df = pd.DataFrame(tweets_list, columns=['id', 'retweet_count', 'favorite_count'])
twitter_archive_df = pd.read_csv('twitter-archive-enhanced.csv')
image_predictions_df = pd.read_csv('image-predictions.tsv', sep='\t')

# %% [markdown]
# ## b) Assessing Data
# This is the stage where the gathered data goes through visual and programatic assessment to dertemine the quality and tidiness of our data. It helps determine the cleaning methods required before the data is fit for visualizations and analysis.

# %% [markdown]
# ### a) tweets_df

# %%
#Read the data set for the tweets, which include; twitter, retweet_count and favorite_count
tweets_df
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %%
#Chech the data types of the column value of the tweet dataframe
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
tweets_df.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
#Checking the first 5 rows of the dataset.
tweets_df.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
#Checking the last 5 rows of the dataset.
tweets_df.tail()
# Out:
#                       id  retweet_count  favorite_count
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535

# %%
len(tweets_df['id'].unique())
# Out:
# 2354

# %%
#Check for the duplicated tweets in the tweets dataset
tweets_df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### b) twitter_archive_df

# %%
#Read the data set for the twitter archive data frame
twitter_archive_df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
len(twitter_archive_df['name'].unique())
# Out:
# 957

# %%
# Display a basic summary of the DataFrame using .info, checking the data types of the columns.
twitter_archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
twitter_archive_df.loc[:, 'name']
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351        None
# 2352           a
# 2353           a
# 2354           a
# 2355        None
# Name: name, Length: 2356, dtype: object

# %%
twitter_archive_df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
#Check for the duplicated tweets in the twitter archive dataset
twitter_archive_df['tweet_id'].duplicated().sum()
# Out:
# 0

# %%
#Checking 55 random rows for any issues in the dataset
twitter_archive_df.sample(55)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1993  672609152938721280                    NaN                  NaN
# 2171  669328503091937280                    NaN                  NaN
# 1107  734776360183431168                    NaN                  NaN
# 1566  687841446767013888                    NaN                  NaN
# 1421  698195409219559425                    NaN                  NaN
# 2307  666826780179869698                    NaN                  NaN
# 394   825829644528148480                    NaN                  NaN
# 1417  698549713696649216                    NaN                  NaN
# 1715  680221482581123072                    NaN                  NaN
# 896   759099523532779520                    NaN                  NaN
# 250   845098359547420673                    NaN                  NaN
# 183   856543823941562368                    NaN                  NaN
# 1855  675531475945709568                    NaN                  NaN
# 745   780092040432480260                    NaN                  NaN
# 307   835685285446955009                    NaN                  NaN
# 320   834458053273591808                    NaN                  NaN
# 2331  666353288456101888                    NaN                  NaN
# 1611  685325112850124800                    NaN                  NaN
# 1879  675015141583413248                    NaN                  NaN
# 1469  694183373896572928                    NaN                  NaN
# 639   793256262322548741                    NaN                  NaN
# 1404  699370870310113280                    NaN                  NaN
# 410   823322678127919110                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 628   794926597468000259                    NaN                  NaN
# 753   778774459159379968                    NaN                  NaN
# 770   776819012571455488                    NaN                  NaN
# 1073  739932936087216128                    NaN                  NaN
# 2165  669367896104181761                    NaN                  NaN
# 2081  670822709593571328                    NaN                  NaN
# 1491  692894228850999298                    NaN                  NaN
# 1101  735635087207878657                    NaN                  NaN
# 1275  709179584944730112                    NaN                  NaN
# 270   841314665196081154                    NaN                  NaN
# 336   832636094638288896                    NaN                  NaN
# 961   751132876104687617                    NaN                  NaN
# 666   790581949425475584                    NaN                  NaN
# 2301  667044094246576128                    NaN                  NaN
# 918   756651752796094464                    NaN                  NaN
# 664   790723298204217344                    NaN                  NaN
# 574   801127390143516673                    NaN                  NaN
# 696   786664955043049472                    NaN                  NaN
# 718   783466772167098368                    NaN                  NaN
# 557   803380650405482500                    NaN                  NaN
# 597   798694562394996736                    NaN                  NaN
# 258   843604394117681152                    NaN                  NaN
# 996   748337862848962560                    NaN                  NaN
# 515   811386762094317568                    NaN                  NaN
# 1933  674019345211760640                    NaN                  NaN
# 274   840698636975636481           8.406983e+17         8.405479e+17
# 1739  679511351870550016                    NaN                  NaN
# 1745  679148763231985668                    NaN                  NaN
# 416   822610361945911296                    NaN                  NaN
# 60    880465832366813184                    NaN                  NaN
# 724   782747134529531904                    NaN                  NaN
#
#                       timestamp  \
# 1993  2015-12-04 02:51:33 +0000
# 2171  2015-11-25 01:35:25 +0000
# 1107  2016-05-23 16:01:50 +0000
# 1566  2016-01-15 03:39:15 +0000
# 1421  2016-02-12 17:22:12 +0000
# 2307  2015-11-18 03:54:28 +0000
# 394   2017-01-29 22:15:05 +0000
# 1417  2016-02-13 16:50:04 +0000
# 1715  2015-12-25 03:00:14 +0000
# 896   2016-07-29 18:53:24 +0000
# 250   2017-03-24 02:22:04 +0000
# 183   2017-04-24 16:22:16 +0000
# 1855  2015-12-12 04:23:49 +0000
# 745   2016-09-25 17:10:10 +0000
# 307   2017-02-26 02:57:52 +0000
# 320   2017-02-22 17:41:18 +0000
# 2331  2015-11-16 20:32:58 +0000
# 1611  2016-01-08 05:00:14 +0000
# 1879  2015-12-10 18:12:05 +0000
# 1469  2016-02-01 15:39:48 +0000
# 639   2016-11-01 01:00:05 +0000
# 1404  2016-02-15 23:13:03 +0000
# 410   2017-01-23 00:13:17 +0000
# 12    2017-07-25 01:55:32 +0000
# 628   2016-11-05 15:37:24 +0000
# 753   2016-09-22 01:54:34 +0000
# 770   2016-09-16 16:24:19 +0000
# 1073  2016-06-06 21:32:13 +0000
# 2165  2015-11-25 04:11:57 +0000
# 2081  2015-11-29 04:32:51 +0000
# 1491  2016-01-29 02:17:12 +0000
# 1101  2016-05-26 00:54:06 +0000
# 1275  2016-03-14 00:49:23 +0000
# 270   2017-03-13 15:47:01 +0000
# 336   2017-02-17 17:01:29 +0000
# 961   2016-07-07 19:16:47 +0000
# 666   2016-10-24 15:53:19 +0000
# 2301  2015-11-18 18:17:59 +0000
# 918   2016-07-23 00:46:50 +0000
# 664   2016-10-25 01:14:59 +0000
# 574   2016-11-22 18:17:08 +0000
# 696   2016-10-13 20:28:35 +0000
# 718   2016-10-05 00:40:09 +0000
# 557   2016-11-28 23:30:47 +0000
# 597   2016-11-16 01:09:57 +0000
# 258   2017-03-19 23:25:35 +0000
# 996   2016-06-30 02:10:24 +0000
# 515   2016-12-21 01:44:13 +0000
# 1933  2015-12-08 00:15:09 +0000
# 274   2017-03-11 22:59:09 +0000
# 1739  2015-12-23 03:58:25 +0000
# 1745  2015-12-22 03:57:37 +0000
# 416   2017-01-21 01:02:48 +0000
# 60    2017-06-29 16:39:47 +0000
# 724   2016-10-03 01:00:34 +0000
#
#                                                  source  \
# 1993  <a href="http://twitter.com/download/iphone" r...
# 2171  <a href="http://twitter.com/download/iphone" r...
# 1107  <a href="http://twitter.com/download/iphone" r...
# 1566  <a href="http://vine.co" rel="nofollow">Vine -...
# 1421  <a href="http://twitter.com/download/iphone" r...
# 2307  <a href="http://twitter.com/download/iphone" r...
# 394   <a href="http://twitter.com/download/iphone" r...
# 1417  <a href="http://twitter.com/download/iphone" r...
# 1715  <a href="http://twitter.com/download/iphone" r...
# 896   <a href="http://twitter.com/download/iphone" r...
# 250   <a href="http://twitter.com/download/iphone" r...
# 183   <a href="http://twitter.com/download/iphone" r...
# 1855  <a href="http://twitter.com/download/iphone" r...
# 745   <a href="http://twitter.com/download/iphone" r...
# 307   <a href="http://twitter.com/download/iphone" r...
# 320   <a href="http://twitter.com/download/iphone" r...
# 2331  <a href="http://twitter.com/download/iphone" r...
# 1611  <a href="http://twitter.com/download/iphone" r...
# 1879  <a href="http://twitter.com/download/iphone" r...
# 1469  <a href="http://twitter.com/download/iphone" r...
# 639   <a href="http://twitter.com/download/iphone" r...
# 1404  <a href="http://twitter.com/download/iphone" r...
# 410   <a href="http://twitter.com/download/iphone" r...
# 12    <a href="http://twitter.com/download/iphone" r...
# 628   <a href="http://twitter.com/download/iphone" r...
# 753   <a href="http://twitter.com/download/iphone" r...
# 770   <a href="http://twitter.com/download/iphone" r...
# 1073  <a href="http://twitter.com/download/iphone" r...
# 2165  <a href="http://twitter.com/download/iphone" r...
# 2081  <a href="http://twitter.com/download/iphone" r...
# 1491  <a href="http://twitter.com/download/iphone" r...
# 1101  <a href="http://twitter.com/download/iphone" r...
# 1275  <a href="http://vine.co" rel="nofollow">Vine -...
# 270   <a href="http://twitter.com" rel="nofollow">Tw...
# 336   <a href="http://twitter.com/download/iphone" r...
# 961   <a href="http://twitter.com/download/iphone" r...
# 666   <a href="http://twitter.com/download/iphone" r...
# 2301  <a href="http://twitter.com/download/iphone" r...
# 918   <a href="http://twitter.com/download/iphone" r...
# 664   <a href="http://twitter.com/download/iphone" r...
# 574   <a href="http://twitter.com/download/iphone" r...
# 696   <a href="http://twitter.com/download/iphone" r...
# 718   <a href="http://twitter.com/download/iphone" r...
# 557   <a href="http://twitter.com/download/iphone" r...
# 597   <a href="http://twitter.com/download/iphone" r...
# 258   <a href="http://twitter.com/download/iphone" r...
# 996   <a href="http://vine.co" rel="nofollow">Vine -...
# 515   <a href="http://twitter.com/download/iphone" r...
# 1933  <a href="http://twitter.com/download/iphone" r...
# 274   <a href="http://twitter.com/download/iphone" r...
# 1739  <a href="http://twitter.com/download/iphone" r...
# 1745  <a href="http://twitter.com/download/iphone" r...
# 416   <a href="http://twitter.com/download/iphone" r...
# 60    <a href="http://twitter.com/download/iphone" r...
# 724   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1993  This is Caryl. Likes to get in the microwave. ...                  NaN
# 2171  This is Kirk. He just saw a bacon wrapped tenn...                  NaN
# 1107  This is Livvie. Someone should tell her it's b...                  NaN
# 1566  13/10 I can't stop watching this (vid by @k8ly...                  NaN
# 1421  Meet Beau &amp; Wilbur. Wilbur stole Beau's be...                  NaN
# 2307  12/10 simply brilliant pup https://t.co/V6ZzG4...                  NaN
# 394   This is Toby. He just found out you only prete...                  NaN
# 1417  This is Claude. He's trying to be seductive bu...                  NaN
# 1715  This is CeCe. She's patiently waiting for Sant...                  NaN
# 896   Meet Toby. He has a drinking problem. Inflatab...                  NaN
# 250   RT @dog_rates: This is Bungalo. She uses that ...         7.733088e+17
# 183   This is Callie. She'll be your navigator today...                  NaN
# 1855  This is Ellie AKA Queen Slayer of the Orbs. Ve...                  NaN
# 745   RT @dog_rates: This is Hank. He's mischievous ...         7.533757e+17
# 307   RT @dog_rates: This is Rory. He's got an inter...         7.869631e+17
# 320   Meet Chester (bottom) &amp; Harold (top). They...                  NaN
# 2331  Here we have a mixed Asiago from the Galápagos...                  NaN
# 1611  "Tristan do not speak to me with that kind of ...                  NaN
# 1879  Meet Moe. He's a golden Fetty Woof. Doesn't re...                  NaN
# 1469  This is Lola. She realized mid hug that she's ...                  NaN
# 639   Oh h*ck look at this spookling right here. Fri...                  NaN
# 1404  Say hello to Calbert. He doesn't have enough l...                  NaN
# 410   This is Wyatt. He's got the fastest paws in th...                  NaN
# 12    Here's a puppo that seems to be on the fence a...                  NaN
# 628   This is Mack. He's rather h*ckin sleepy. Excep...                  NaN
# 753   RT @dog_rates: In case you haven't seen the mo...         7.580996e+17
# 770   RT @dog_rates: Everybody look at this beautifu...         6.798284e+17
# 1073  Say hello to Rorie. She's zen af. Just enjoyin...                  NaN
# 2165  This is Chip. Chip's pretending to be choked. ...                  NaN
# 2081  Can't do better than this lol. 10/10 for the o...                  NaN
# 1491  Meet Tupawc. He's actually a Christian rapper....                  NaN
# 1101  This is Dakota. He hasn't grow into his skin y...                  NaN
# 1275  This is Sammy. He's in a tree. Very excited ab...                  NaN
# 270   This is Max. There's no way in h*ck you're tak...                  NaN
# 336   This is Orion. He just got back from the denti...                  NaN
# 961   This is Cooper. He's just so damn happy. 10/10...                  NaN
# 666   This is Duke. He sneaks into the fridge someti...                  NaN
# 2301            12/10 gimme now https://t.co/QZAnwgnOMB                  NaN
# 918   This is Gert. He just wants you to be happy. 1...                  NaN
# 664   RT @dog_rates: This is Happy. He's a bathtub r...         7.899865e+17
# 574   RT @dog_rates: This is Anakin. He strives to r...         7.757333e+17
# 696   "Honestly Kathleen I just want more Ken Bone" ...                  NaN
# 718   This is Finn. He likes eavesdropping from fili...                  NaN
# 557   Meet Sonny. He's an in-home movie critic. That...                  NaN
# 597   RT @dog_rates: I'm not sure what's happening h...         7.012147e+17
# 258   This is Hank. He's been outside for 3 minutes ...                  NaN
# 996   SWIM AWAY PUPPER SWIM AWAY 13/10 #BarkWeek  ht...                  NaN
# 515   This is Craig. That's actually a normal sized ...                  NaN
# 1933  This is Acro. You briefly see her out of the c...                  NaN
# 274   @0_kelvin_0 &gt;10/10 is reserved for puppos s...                  NaN
# 1739  Say hello to William. He makes fun of others b...                  NaN
# 1745  I know everyone's excited for Christmas but th...                  NaN
# 416   Please stop sending in non-canines like this V...                  NaN
# 60    This is Bella. She had her first beach experie...                  NaN
# 724   This is Deacon. He's the happiest almost dry d...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1993                       NaN                        NaN
# 2171                       NaN                        NaN
# 1107                       NaN                        NaN
# 1566                       NaN                        NaN
# 1421                       NaN                        NaN
# 2307                       NaN                        NaN
# 394                        NaN                        NaN
# 1417                       NaN                        NaN
# 1715                       NaN                        NaN
# 896                        NaN                        NaN
# 250               4.196984e+09  2016-09-06 23:56:05 +0000
# 183                        NaN                        NaN
# 1855                       NaN                        NaN
# 745               4.196984e+09  2016-07-13 23:48:51 +0000
# 307               4.196984e+09  2016-10-14 16:13:10 +0000
# 320                        NaN                        NaN
# 2331                       NaN                        NaN
# 1611                       NaN                        NaN
# 1879                       NaN                        NaN
# 1469                       NaN                        NaN
# 639                        NaN                        NaN
# 1404                       NaN                        NaN
# 410                        NaN                        NaN
# 12                         NaN                        NaN
# 628                        NaN                        NaN
# 753               4.196984e+09  2016-07-27 00:40:12 +0000
# 770               4.196984e+09  2015-12-24 00:58:27 +0000
# 1073                       NaN                        NaN
# 2165                       NaN                        NaN
# 2081                       NaN                        NaN
# 1491                       NaN                        NaN
# 1101                       NaN                        NaN
# 1275                       NaN                        NaN
# 270                        NaN                        NaN
# 336                        NaN                        NaN
# 961                        NaN                        NaN
# 666                        NaN                        NaN
# 2301                       NaN                        NaN
# 918                        NaN                        NaN
# 664               4.196984e+09  2016-10-23 00:27:05 +0000
# 574               4.196984e+09  2016-09-13 16:30:07 +0000
# 696                        NaN                        NaN
# 718                        NaN                        NaN
# 557                        NaN                        NaN
# 597               4.196984e+09  2016-02-21 01:19:47 +0000
# 258                        NaN                        NaN
# 996                        NaN                        NaN
# 515                        NaN                        NaN
# 1933                       NaN                        NaN
# 274                        NaN                        NaN
# 1739                       NaN                        NaN
# 1745                       NaN                        NaN
# 416                        NaN                        NaN
# 60                         NaN                        NaN
# 724                        NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1993  https://twitter.com/dog_rates/status/672609152...                 9
# 2171  https://twitter.com/dog_rates/status/669328503...                12
# 1107  https://twitter.com/dog_rates/status/734776360...                11
# 1566                      https://vine.co/v/iOWwUPH1hrw                13
# 1421  https://twitter.com/dog_rates/status/698195409...                 9
# 2307  https://twitter.com/dog_rates/status/666826780...                12
# 394   https://twitter.com/dog_rates/status/825829644...                12
# 1417  https://twitter.com/dog_rates/status/698549713...                 9
# 1715  https://twitter.com/dog_rates/status/680221482...                10
# 896   https://twitter.com/dog_rates/status/759099523...                 7
# 250   https://twitter.com/dog_rates/status/773308824...                12
# 183   https://twitter.com/dog_rates/status/856543823...                12
# 1855  https://twitter.com/dog_rates/status/675531475...                10
# 745   https://twitter.com/dog_rates/status/753375668...                 8
# 307   https://twitter.com/dog_rates/status/786963064...                12
# 320   https://twitter.com/dog_rates/status/834458053...                12
# 2331  https://twitter.com/dog_rates/status/666353288...                 8
# 1611  https://twitter.com/dog_rates/status/685325112...                10
# 1879  https://twitter.com/dog_rates/status/675015141...                10
# 1469  https://twitter.com/dog_rates/status/694183373...                 9
# 639   https://twitter.com/dog_rates/status/793256262...                12
# 1404  https://twitter.com/dog_rates/status/699370870...                11
# 410   https://twitter.com/dog_rates/status/823322678...                11
# 12    https://twitter.com/dog_rates/status/889665388...                13
# 628   https://twitter.com/dog_rates/status/794926597...                12
# 753   https://vine.co/v/hQJbaj1VpIz,https://vine.co/...                13
# 770   https://twitter.com/dog_rates/status/679828447...                13
# 1073  https://twitter.com/dog_rates/status/739932936...                10
# 2165  https://twitter.com/dog_rates/status/669367896...                10
# 2081  https://twitter.com/dog_rates/status/670822709...                10
# 1491  https://twitter.com/dog_rates/status/692894228...                10
# 1101  https://twitter.com/dog_rates/status/735635087...                11
# 1275                      https://vine.co/v/iwAjdlEjwMl                13
# 270   https://twitter.com/dog_rates/status/841314665...                13
# 336   https://twitter.com/dog_rates/status/832636094...                12
# 961   https://twitter.com/dog_rates/status/751132876...                10
# 666   https://twitter.com/dog_rates/status/790581949...                11
# 2301  https://twitter.com/dog_rates/status/667044094...                12
# 918   https://twitter.com/dog_rates/status/756651752...                11
# 664   https://twitter.com/dog_rates/status/789986466...                12
# 574   https://twitter.com/dog_rates/status/775733305...                11
# 696   https://twitter.com/dog_rates/status/786664955...                12
# 718   https://twitter.com/dog_rates/status/783466772...                11
# 557   https://twitter.com/dog_rates/status/803380650...                12
# 597   https://twitter.com/dog_rates/status/701214700...                12
# 258   https://twitter.com/dog_rates/status/843604394...                11
# 996                       https://vine.co/v/h5aDaFthX6O                13
# 515   https://twitter.com/dog_rates/status/811386762...                11
# 1933  https://twitter.com/dog_rates/status/674019345...                10
# 274                                                 NaN                10
# 1739  https://twitter.com/dog_rates/status/679511351...                 7
# 1745  https://twitter.com/dog_rates/status/679148763...                 8
# 416   https://twitter.com/dog_rates/status/822610361...                12
# 60    https://twitter.com/dog_rates/status/880465832...                12
# 724   https://twitter.com/dog_rates/status/782747134...                11
#
#       rating_denominator     name  doggo floofer  pupper  puppo
# 1993                  10    Caryl   None    None    None   None
# 2171                  10     Kirk   None    None    None   None
# 1107                  10   Livvie   None    None    None   None
# 1566                  10     None   None    None    None   None
# 1421                  10     Beau   None    None    None   None
# 2307                  10     None   None    None    None   None
# 394                   10     Toby   None    None    None   None
# 1417                  10   Claude   None    None    None   None
# 1715                  10     CeCe   None    None    None   None
# 896                   10     Toby   None    None    None   None
# 250                   10  Bungalo   None    None    None   None
# 183                   10   Callie   None    None    None   None
# 1855                  10    Ellie   None    None    None   None
# 745                   10     Hank   None    None    None   None
# 307                   10     Rory   None    None    None   None
# 320                   10  Chester   None    None    None   None
# 2331                  10     None   None    None    None   None
# 1611                  10     None   None    None    None   None
# 1879                  10      Moe   None    None    None   None
# 1469                  10     Lola   None    None    None   None
# 639                   10     None   None    None    None   None
# 1404                  10  Calbert   None    None    None   None
# 410                   10    Wyatt   None    None    None   None
# 12                    10     None   None    None    None  puppo
# 628                   10     Mack   None    None    None   None
# 753                   10     None   None    None    None   None
# 770                   10     None   None    None  pupper   None
# 1073                  10    Rorie   None    None    None   None
# 2165                  10     Chip   None    None    None   None
# 2081                  10     None   None    None    None   None
# 1491                  10   Tupawc   None    None    None   None
# 1101                  10   Dakota   None    None    None   None
# 1275                  10    Sammy   None    None    None   None
# 270                   10      Max   None    None    None   None
# 336                   10    Orion   None    None    None   None
# 961                   10   Cooper   None    None    None  puppo
# 666                   10     Duke   None    None    None   None
# 2301                  10     None   None    None    None   None
# 918                   10     Gert   None    None    None   None
# 664                   10    Happy   None    None    None   None
# 574                   10   Anakin  doggo    None    None   None
# 696                   10     None   None    None    None   None
# 718                   10     Finn   None    None    None   None
# 557                   10    Sonny   None    None    None   None
# 597                   10     None   None    None    None   None
# 258                   10     Hank   None    None    None   None
# 996                   10     None   None    None  pupper   None
# 515                   10    Craig   None    None  pupper   None
# 1933                  10     Acro   None    None    None   None
# 274                   10     None   None    None    None   None
# 1739                  10  William   None    None    None   None
# 1745                  10     None   None    None    None   None
# 416                   10     None   None    None    None   None
# 60                    10    Bella   None    None    None   None
# 724                   10   Deacon  doggo    None    None   None

# %%
twitter_archive_df[twitter_archive_df['retweeted_status_user_id'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2175 rows x 17 columns]

# %% [markdown]
# ### c) image_predictions_df

# %%
#Read the data set for the image prediction data sets.
image_predictions_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
image_predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions_df.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
image_predictions_df.iloc[:, 3]
# Out:
# 0       Welsh_springer_spaniel
# 1                      redbone
# 2              German_shepherd
# 3          Rhodesian_ridgeback
# 4           miniature_pinscher
#                  ...
# 2070                    basset
# 2071               paper_towel
# 2072                 Chihuahua
# 2073                 Chihuahua
# 2074                    orange
# Name: p1, Length: 2075, dtype: object

# %%
# checking fo the total number of unique value in every column
image_predictions_df.nunique()
# Out:
# tweet_id    2075
# jpg_url     2009
# img_num        4
# p1           378
# p1_conf     2006
# p1_dog         2
# p2           405
# p2_conf     2004
# p2_dog         2
# p3           408
# p3_conf     2006
# p3_dog         2
# dtype: int64

# %%
#Listing the invalid data that does not have dog breeds and name it 'image_predictions_1'
image_predictions_1=image_predictions_df[image_predictions_df['p1_dog']==False]
#check to confirm success
image_predictions_1
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# ...                  ...                                                ...
# 2026  882045870035918850    https://pbs.twimg.com/media/DD2oCl2WAAEI_4a.jpg
# 2046  886680336477933568    https://pbs.twimg.com/media/DE4fEDzWAAAyHMM.jpg
# 2052  887517139158093824  https://pbs.twimg.com/ext_tw_video_thumb/88751...
# 2071  891689557279858688    https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2074  892420643555336193    https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                p1   p1_conf  p1_dog                  p2  \
# 6           1        box_turtle  0.933012   False          mud_turtle
# 8           1     shopping_cart  0.962465   False     shopping_basket
# 17          1               hen  0.965932   False                cock
# 18          1  desktop_computer  0.086502   False                desk
# 21          1  three-toed_sloth  0.914671   False               otter
# ...       ...               ...       ...     ...                 ...
# 2026        1          web_site  0.949591   False               dhole
# 2046        1       convertible  0.738995   False          sports_car
# 2052        1         limousine  0.130432   False           tow_truck
# 2071        1       paper_towel  0.170278   False  Labrador_retriever
# 2074        1            orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                p3   p3_conf  p3_dog
# 6     0.045885   False          terrapin  0.017885   False
# 8     0.014594   False  golden_retriever  0.007959    True
# 17    0.033919   False         partridge  0.000052   False
# 18    0.085547   False          bookcase  0.079480   False
# 21    0.015250   False    great_grey_owl  0.013207   False
# ...        ...     ...               ...       ...     ...
# 2026  0.017326   False  golden_retriever  0.006941    True
# 2046  0.139952   False         car_wheel  0.044173   False
# 2052  0.029175   False     shopping_cart  0.026321   False
# 2071  0.168086    True           spatula  0.040836   False
# 2074  0.085851   False            banana  0.076110   False
#
# [543 rows x 12 columns]

# %%
image_predictions_1.p1.value_counts()
# Out:
# seat_belt        22
# web_site         19
# teddy            18
# dingo             9
# tennis_ball       9
#                  ..
# walking_stick     1
# book_jacket       1
# rain_barrel       1
# guenon            1
# orange            1
# Name: p1, Length: 267, dtype: int64

# %% [markdown]
# ## Quality Issues
# List the quality issues identified while assessing the data.
# ###### `twitter_archive` data
# - Missing values (NaN)
# - Presence of 'None' entries
# - Misrepresentation of some dog names as 'a', 'none', 'an', 'the'....
# - Unnecessary data in columns ("in_reply_to_status_id", "in_reply_to_user_id", "timestamp", "retweeted_status_id", "retweeted_status_user_id" and "retweeted_status_timestamp" columns)
# - Non descriptive column headers, "text", "name".....
# - tweet_id is registered as a integer instead of a string in `twitter_archive`
# - Multiple columns which should have been represented as strings are represented as floats i.e "in_reply_to_status_id", "in_reply_to_user_id", "retweeted_status_id" and "retweeted_status_user_id"
#
# ###### `image_predictions` data
# - Mixing of lowercase and uppercase of names in column "p1", "p2" and "p3"
# - tweet_id is registered as a integer instead of a string in `image_predictions`
#
#
# ###### `tweets_df` data
# - None descriptive column header 'id'.
# - The entries in the "id" column of the  `tweets_df` treated as an integer instead of a string
#
#
# ###### `Tidiness`
# - Dog stages i.e doggo, floofer, pupper and puppo have been represented in 4 different columns in stead of one.
# - The tweet information is spread through 3 different data frames instead of one.
# - Two datasets represented in one column instead of 2 i.e 'timestamp' has both date and time in the same column.
# - Having same observations represented in 3 different columns i.e "p1" "p2" "p3" columns, p1_conf p2_conf p3_conf columns and p1_dog p2_dog p3_dog columns.

# %% [markdown]
# ## c) Cleaning process
# This is the stage where the collected data is corrected for any corrupt or inaccurate. This improves the quality and tidiness of the dataset and makes it easier for the exploratory data analysis stage.
# For easier understanding of the process, its divided into 3 different stages.
#
# #### Define:
# - Define the issues detected.
#
# #### Code
# - Create a code to clean the issue.
#
# #### Test
# - Perform a test-run in the resulting code to see if the issue is fixed.

# %%
#Create copies of the collected dataframes
tweets_df_clean = tweets_df.copy()
twitter_archive_df_clean = twitter_archive_df.copy()
image_predictions_df_clean = image_predictions_df.copy()

# %% [markdown]
# ### None descriptive column headers, "text", "name"......in the twitter archive data frame
# #### Define
# - Rename the 2 none descriptive columns in the data frame i.e 'name' renamed to 'dog_name' and 'text' renamed to 'text_tweeted'
#
#
#
# #### Clean: Code 1

# %%
#Replacing the nondescriptive column names on the copy of the twitter archive data frames with more descriptive column names, ie 'name' to 'dog_name', 'text' to 'text_tweeted'. 
twitter_archive_df_clean = twitter_archive_df_clean.rename(columns={'name':'dog_name','text':'text_tweeted'})

# %% [markdown]
# #### Test

# %%
#Check to see for success.
twitter_archive_df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  dog_name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %% [markdown]
# ### None descriptive column header 'id' in tweets_df.
# #### Define
# - Rename the "id" column  to "tweet_id"
#
#
#
# #### Clean: Code 2

# %%
#Replacing the nondescriptive column name on the copy of the tweets data frames with more descriptive column names, ie 'id' to 'tweet_id'. 
tweets_df_clean = tweets_df_clean.rename(columns={'id':'tweet_id'})

# %% [markdown]
# #### Test

# %%
#Check to confirm success
tweets_df_clean
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %% [markdown]
# #### Presence of retweets.
# #### Define
# - Rename the rows with retweeted data in"twitter_archive_df"
#
#
#
# #### Clean: Code 3

# %%
#Listing rows with none retwitted retweets and assigning them new data frame names.
df_twitter_archive_df_clean1 = twitter_archive_df_clean[twitter_archive_df_clean.retweeted_status_id.isnull()]
df_twitter_archive_df_clean2 = twitter_archive_df_clean[twitter_archive_df_clean.retweeted_status_user_id.isnull()]
df_twitter_archive_df_clean3 = twitter_archive_df_clean[twitter_archive_df_clean.retweeted_status_timestamp.isnull()]

# %%
#Merge the 3 data sets formed asa a resupt of getting rid of the null retweets i.e df_twitter_archive_df_clean1, df_twitter_archive_df_clean2 and df_twitter_archive_df_clean3
df_twitter_archive_null=pd.concat([df_twitter_archive_df_clean1,df_twitter_archive_df_clean2,df_twitter_archive_df_clean3])

# %%
#Drop duplicated rows in the new dataset
df_twitter_archive_null.drop_duplicates(subset='tweet_id', keep='first', inplace=True)

# %% [markdown]
# #### Test
# - Perform a test-run in the resulting code to see if the issue is fixed.

# %%
df_twitter_archive_null
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  dog_name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2175 rows x 17 columns]

# %% [markdown]
# ### Mixing of lowercase and uppercase of names in column "p1", "p2" and "p3" in `image_predictions` data
# #### Define
# - Convert all the names in columns p1, p2 and p3 to lowercase.
#
#
#
# #### Clean: Code 4

# %%
image_predictions_df_clean = image_predictions_df_clean[['tweet_id', 'jpg_url', 'img_num','p1', 'p1_conf', 'p1_dog','p2', 'p2_conf', 'p2_dog','p3', 'p3_conf', 'p3_dog']]
image_predictions_df_clean.p1 = image_predictions_df_clean.p1.str.lower()
image_predictions_df_clean.p2 = image_predictions_df_clean.p2.str.lower()
image_predictions_df_clean.p3 = image_predictions_df_clean.p3.str.lower()

# %%
image_predictions_df_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         german_shepherd  0.596461    True            malinois
# 3           1     rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    english_springer
# 2071        1             paper_towel  0.170278   False  labrador_retriever
# 2072        1               chihuahua  0.716012    True            malamute
# 2073        1               chihuahua  0.323581    True            pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            shetland_sheepdog  0.061428    True
# 1     0.074192    True          rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  german_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
image_predictions_df_clean.sample(55)
# Out:
#                 tweet_id                                            jpg_url  \
# 1454  777189768882946048    https://pbs.twimg.com/media/Cskh9nRWYAAUxBP.jpg
# 1474  780459368902959104    https://pbs.twimg.com/media/CtS_p9kXEAE2nh8.jpg
# 1572  795076730285391872    https://pbs.twimg.com/media/CwiuEJmW8AAZnit.jpg
# 1430  773191612633579521    https://pbs.twimg.com/media/CrrtqjdXEAINleR.jpg
# 1805  832273440279240704  https://pbs.twimg.com/ext_tw_video_thumb/83227...
# 1133  728409960103686147    https://pbs.twimg.com/media/ChvU_DwWMAArx5L.jpg
# 396   673656262056419329    https://pbs.twimg.com/media/CVlOy3pW4AQ9H1K.jpg
# 1780  828650029636317184    https://pbs.twimg.com/media/C3_0yhCWEAETXj2.jpg
# 1102  721001180231503872    https://pbs.twimg.com/media/CgGCvxAUkAAx55r.jpg
# 967   706310011488698368    https://pbs.twimg.com/media/Cc1RNHLW4AACG6H.jpg
# 1681  813812741911748608    https://pbs.twimg.com/media/C0s-XtzWgAAp1W-.jpg
# 668   683030066213818368    https://pbs.twimg.com/media/CXqcOHCUQAAugTB.jpg
# 130   668291999406125056    https://pbs.twimg.com/media/CUZABzGW4AE5F0k.jpg
# 1156  733460102733135873    https://pbs.twimg.com/media/Ci3GDeyUoAAKOxn.jpg
# 262   670789397210615808    https://pbs.twimg.com/media/CU8fZSQWoAEVp6O.jpg
# 847   695409464418041856    https://pbs.twimg.com/media/CaaXN5LUYAEzAh-.jpg
# 858   696886256886657024    https://pbs.twimg.com/media/CavWWdFWAAArflW.jpg
# 1369  761976711479193600    https://pbs.twimg.com/media/CpMVxoRXgAAh350.jpg
# 1744  822872901745569793    https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg
# 1299  752519690950500352    https://pbs.twimg.com/media/CnF8qVDWYAAh0g1.jpg
# 192   669567591774625800    https://pbs.twimg.com/media/CUrIK1DWoAAhECq.jpg
# 637   681261549936340994    https://pbs.twimg.com/media/CXRTw_5WMAAUDVp.jpg
# 139   668542336805281792    https://pbs.twimg.com/media/CUcjtL8WUAAAJoz.jpg
# 1512  786363235746385920    https://pbs.twimg.com/media/Cum5LlfWAAAyPcS.jpg
# 355   672594978741354496    https://pbs.twimg.com/media/CVWJkJXWsAInlZl.jpg
# 558   677698403548192770    https://pbs.twimg.com/media/CWerGmOXAAAm6NY.jpg
# 77    667437278097252352    https://pbs.twimg.com/media/CUM2qWaWoAUZ06L.jpg
# 1139  729463711119904772    https://pbs.twimg.com/media/Ch-TXpFXAAAwPGf.jpg
# 338   672239279297454080    https://pbs.twimg.com/media/CVRGDrsWsAAUWSF.jpg
# 196   669597912108789760    https://pbs.twimg.com/media/CUrjvxiVEAA94dH.jpg
# 1313  754747087846248448    https://pbs.twimg.com/media/CnlmeL3WgAA4c84.jpg
# 73    667369227918143488    https://pbs.twimg.com/media/CUL4xR9UkAEdlJ6.jpg
# 796   690959652130045952    https://pbs.twimg.com/media/CZbIIM-WkAIPClg.jpg
# 768   689280876073582592    https://pbs.twimg.com/media/CZDRTAPUoAEaqxF.jpg
# 998   708469915515297792    https://pbs.twimg.com/media/CdT9n7mW0AQcpZU.jpg
# 563   678021115718029313    https://pbs.twimg.com/media/CWjQm5gXAAA9GkD.jpg
# 1452  776813020089548800    https://pbs.twimg.com/media/CsfLUDbXEAAu0VF.jpg
# 1987  872620804844003328    https://pbs.twimg.com/media/DBwr_hzXkAEnZBW.jpg
# 450   674739953134403584    https://pbs.twimg.com/media/CV0oaHFW4AA9Coi.jpg
# 894   699434518667751424    https://pbs.twimg.com/media/CbTj--1XEAIZjc_.jpg
# 1195  740365076218183684    https://pbs.twimg.com/media/CkZOGhJWsAAHvPv.jpg
# 239   670435821946826752    https://pbs.twimg.com/media/CU3d0azWUAA38FD.jpg
# 240   670442337873600512    https://pbs.twimg.com/media/CU3jwAYWwAAhdAv.jpg
# 1740  822489057087389700    https://pbs.twimg.com/media/C2oRbOuWEAAbVSl.jpg
# 915   701214700881756160    https://pbs.twimg.com/media/Cbs3DOAXIAAp3Bd.jpg
# 276   670840546554966016    https://pbs.twimg.com/media/CU9N6upXAAAbtQe.jpg
# 898   699779630832685056    https://pbs.twimg.com/media/CbYd3C9WEAErJ4Z.jpg
# 511   676191832485810177    https://pbs.twimg.com/media/CWJQ4UmWoAIJ29t.jpg
# 992   708109389455101952    https://pbs.twimg.com/media/CdO1u9vWAAApj2V.jpg
# 642   681339448655802368    https://pbs.twimg.com/media/CXSanNkWkAAqR9M.jpg
# 1136  728760639972315136    https://pbs.twimg.com/media/Ch0T71OWMAA4yIw.jpg
# 509   676101918813499392    https://pbs.twimg.com/media/CWH_FTgWIAAwOUy.jpg
# 226   670361874861563904    https://pbs.twimg.com/media/CU2akCQWsAIbaOV.jpg
# 772   689557536375177216    https://pbs.twimg.com/media/CZHM60BWIAA4AY4.jpg
# 1416  771136648247640064    https://pbs.twimg.com/media/CrOgsIBWYAA8Dtb.jpg
#
#       img_num                              p1   p1_conf  p1_dog  \
# 1454        2                       chihuahua  0.988412    True
# 1474        1                      great_dane  0.382491    True
# 1572        2                        gas_pump  0.676439   False
# 1430        1                blenheim_spaniel  0.427766    True
# 1805        1                        pembroke  0.134081    True
# 1133        1                     siamese_cat  0.478278   False
# 396         1                    bull_mastiff  0.700625    True
# 1780        1                golden_retriever  0.649209    True
# 1102        1                         samoyed  0.950053    True
# 967         1                        pembroke  0.698165    True
# 1681        1                  french_bulldog  0.709146    True
# 668         1                           boxer  0.722218    True
# 130         1                        web_site  0.995535   False
# 1156        1                            chow  0.931275    True
# 262         1                          beagle  0.295966    True
# 847         1                             pug  0.997445    True
# 858         1                          kuvasz  0.383941    True
# 1369        3              labrador_retriever  0.475552    True
# 1744        1                lakeland_terrier  0.196015    True
# 1299        3                           swing  0.999984   False
# 192         1                       chihuahua  0.980511    True
# 637         1                 tibetan_terrier  0.382101    True
# 139         1  american_staffordshire_terrier  0.267695    True
# 1512        1                golden_retriever  0.929266    True
# 355         1                  great_pyrenees  0.755945    True
# 558         1                        shih-tzu  0.916645    True
# 77          1                       porcupine  0.989154   False
# 1139        1                 german_shepherd  0.829307    True
# 338         1                             pug  0.332536    True
# 196         1                      eskimo_dog  0.595665    True
# 1313        1                      rotisserie  0.471493   False
# 73          1                           teddy  0.709545   False
# 796         2                golden_retriever  0.862964    True
# 768         3                       chihuahua  0.637546    True
# 998         1                       chihuahua  0.748163    True
# 563         1              miniature_pinscher  0.822048    True
# 1452        1                      toy_poodle  0.516610    True
# 1987        1                  cocker_spaniel  0.513191    True
# 450         1                  dandie_dinmont  0.175915    True
# 894         1                golden_retriever  0.836572    True
# 1195        1                         bow_tie  0.246313   False
# 239         1                          sorrel  0.460370   False
# 240         1                  sussex_spaniel  0.403552    True
# 1740        1                         samoyed  0.416769    True
# 915         1                       chihuahua  0.615163    True
# 276         1                        shih-tzu  0.963622    True
# 898         1                        malinois  0.706038    True
# 511         2                       chihuahua  0.376741    True
# 992         1       staffordshire_bullterrier  0.516106    True
# 642         1                       seat_belt  0.532441   False
# 1136        1                        pembroke  0.939134    True
# 509         1                        shih-tzu  0.225848    True
# 226         1                        platypus  0.974075   False
# 772         1                      eskimo_dog  0.169482    True
# 1416        1                         bathtub  0.368660   False
#
#                                   p2   p2_conf  p2_dog  \
# 1454                mexican_hairless  0.004177    True
# 1474                 german_shepherd  0.312026    True
# 1572                       harvester  0.049995   False
# 1430                        shih-tzu  0.219256    True
# 1805                        ice_bear  0.051928   False
# 1133                   saint_bernard  0.094246    True
# 396              rhodesian_ridgeback  0.094698    True
# 1780        chesapeake_bay_retriever  0.198560    True
# 1102                       washbasin  0.006321   False
# 967                        chihuahua  0.105834    True
# 1681                     boston_bull  0.247621    True
# 668                     bull_mastiff  0.193804    True
# 130                            skunk  0.001363   False
# 1156                          beaver  0.028831   False
# 262                           basset  0.143527    True
# 847                     bull_mastiff  0.001749    True
# 858                 golden_retriever  0.289085    True
# 1369        chesapeake_bay_retriever  0.082898    True
# 1744              labrador_retriever  0.160329    True
# 1299              labrador_retriever  0.000010    True
# 192                      toy_terrier  0.009166    True
# 637                 miniature_poodle  0.095429    True
# 139                   french_bulldog  0.254050    True
# 1512              labrador_retriever  0.062867    True
# 355             old_english_sheepdog  0.082337    True
# 558                            lhasa  0.057883    True
# 77                        bath_towel  0.006300   False
# 1139                        doberman  0.022500    True
# 338                   french_bulldog  0.258124    True
# 196                   siberian_husky  0.214474    True
# 1313                    cash_machine  0.250837   False
# 73                        bath_towel  0.127285   False
# 796               labrador_retriever  0.044865    True
# 768   american_staffordshire_terrier  0.150694    True
# 998                      toy_terrier  0.127717    True
# 563                         doberman  0.096085    True
# 1452                miniature_poodle  0.255033    True
# 1987                  sussex_spaniel  0.159088    True
# 450              black-footed_ferret  0.096534   False
# 894                           kuvasz  0.105946    True
# 1195                     windsor_tie  0.172446   False
# 239                          basenji  0.135767    True
# 240                       otterhound  0.256302    True
# 1740                        malamute  0.252706    True
# 915                         pembroke  0.159509    True
# 276                            lhasa  0.016017    True
# 898                  german_shepherd  0.165655    True
# 511                italian_greyhound  0.173114    True
# 992   american_staffordshire_terrier  0.236075    True
# 642               labrador_retriever  0.094615    True
# 1136                        cardigan  0.054336    True
# 509                  norfolk_terrier  0.186873    True
# 226               spotted_salamander  0.011068   False
# 772                   siberian_husky  0.161655    True
# 1416                golden_retriever  0.297402    True
#
#                              p3   p3_conf  p3_dog
# 1454                        hog  0.001507   False
# 1474               bull_mastiff  0.033272    True
# 1572                      swing  0.044660   False
# 1430     welsh_springer_spaniel  0.144614    True
# 1805                        pug  0.044311    True
# 1133               king_penguin  0.082157   False
# 396           brabancon_griffon  0.057559    True
# 1780                     vizsla  0.056200    True
# 1102                        tub  0.006243   False
# 967                  bloodhound  0.062030    True
# 1681                      boxer  0.018855    True
# 668              french_bulldog  0.055194    True
# 130                      badger  0.000686   False
# 1156                      dhole  0.017379   False
# 262                    bluetick  0.138992    True
# 847                    pekinese  0.000304    True
# 858                       dingo  0.056548   False
# 1369  staffordshire_bullterrier  0.048464    True
# 1744              irish_terrier  0.069126    True
# 1299                 eskimo_dog  0.000001    True
# 192          miniature_pinscher  0.002659    True
# 637                 maltese_dog  0.065738    True
# 139   staffordshire_bullterrier  0.212381    True
# 1512                     saluki  0.002157    True
# 355                afghan_hound  0.027037    True
# 558                    pekinese  0.020126    True
# 77                       badger  0.000966   False
# 1139                    basenji  0.021190    True
# 338                bull_mastiff  0.120873    True
# 196                  white_wolf  0.147235   False
# 1313               sliding_door  0.117872   False
# 73           christmas_stocking  0.028567   False
# 796                      saluki  0.012468    True
# 768   staffordshire_bullterrier  0.103953    True
# 998                    pembroke  0.042141    True
# 563                  rottweiler  0.032709    True
# 1452            standard_poodle  0.168989    True
# 1987            standard_poodle  0.149509    True
# 450                  toy_poodle  0.064145    True
# 894          labrador_retriever  0.025144    True
# 1195                   mushroom  0.137516   False
# 239                    cardigan  0.099174    True
# 240               irish_terrier  0.187315    True
# 1740                     kuvasz  0.157028    True
# 915                     basenji  0.084466    True
# 276                  guinea_pig  0.007932   False
# 898                  great_dane  0.059048    True
# 511                      muzzle  0.071485   False
# 992                      kelpie  0.069750    True
# 642                      kuvasz  0.089863    True
# 1136                  chihuahua  0.005590    True
# 509               irish_terrier  0.106987    True
# 226                       bison  0.003897   False
# 772                       dingo  0.154414   False
# 1416                        tub  0.201711   False

# %% [markdown]
# ### Presence of 'None' entries
# #### Define
# - Replace all the 'None' with NaN in twitter_archive_df_clean
#
#
#
# #### Clean: Code 5

# %%
twitter_archive_df_clean = twitter_archive_df_clean.replace('None',np.NaN)

# %% [markdown]
# #### Test

# %%
twitter_archive_df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  dog_name doggo floofer pupper puppo
# 0                     10   Phineas   NaN     NaN    NaN   NaN
# 1                     10     Tilly   NaN     NaN    NaN   NaN
# 2                     10    Archie   NaN     NaN    NaN   NaN
# 3                     10     Darla   NaN     NaN    NaN   NaN
# 4                     10  Franklin   NaN     NaN    NaN   NaN
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10       NaN   NaN     NaN    NaN   NaN
# 2352                  10         a   NaN     NaN    NaN   NaN
# 2353                  10         a   NaN     NaN    NaN   NaN
# 2354                  10         a   NaN     NaN    NaN   NaN
# 2355                  10       NaN   NaN     NaN    NaN   NaN
#
# [2356 rows x 17 columns]

# %% [markdown]
# ### tweet_id is registered as a interger intead of a string in `image_predictions_df`, `twitter_archive_df` and `tweets_df`
# #### Define
# - Change the 'tweet_id' columns in all the 3 datasets from an int data type to a string datatype
#
#
#
# #### Clean: Code 6

# %%
tweets_df_clean['tweet_id']=tweets_df_clean['tweet_id'].astype('str')
twitter_archive_df_clean['tweet_id']=tweets_df_clean['tweet_id'].astype('str')
image_predictions_df_clean['tweet_id']=tweets_df_clean['tweet_id'].astype('str')

# %% [markdown]
# #### Test

# %%
tweets_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   object
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 55.3+ KB

# %%
twitter_archive_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2354 non-null   object
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text_tweeted                2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  dog_name                    1611 non-null   object
#  13  doggo                       97 non-null     object
#  14  floofer                     10 non-null     object
#  15  pupper                      257 non-null    object
#  16  puppo                       30 non-null     object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 313.0+ KB

# %%
image_predictions_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Dog stages i.e doggo, floofer, pupper and puppo have been repsented in 4 different columns in stead of one.
# #### Define
# - Create a new column named 'dog_stage' and combine the data in the individual columns ('doggo','floofer','pupper','puppo') into the new column created.
#
#
#
# #### Clean: Code 7

# %%
twitter_archive_df_clean['dog_stage'] = twitter_archive_df_clean[twitter_archive_df_clean.columns[13:]].apply(
    lambda x: ','.join(x.dropna().astype(str)), axis=1)
twitter_archive_df_clean.drop(['doggo','floofer','pupper','puppo'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666033412701032449                    NaN                  NaN
# 2352  666029285002620928                    NaN                  NaN
# 2353  666020888022790149                    NaN                  NaN
# 2354                 NaN                    NaN                  NaN
# 2355                 NaN                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  dog_name dog_stage
# 0                     10   Phineas
# 1                     10     Tilly
# 2                     10    Archie
# 3                     10     Darla
# 4                     10  Franklin
# ...                  ...       ...       ...
# 2351                  10       NaN
# 2352                  10         a
# 2353                  10         a
# 2354                  10         a
# 2355                  10       NaN
#
# [2356 rows x 14 columns]

# %% [markdown]
# ### Missrepresentation of some dog names as 'a', 'none', 'an', 'the'....

# %%
y=['a', 'none', 'an', 'the']
df_y=twitter_archive_df_clean[twitter_archive_df_clean.dog_name.isin(y)]
df_y
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881268444196462592                    NaN                  NaN
# 649   792883833364439040                    NaN                  NaN
# 759   778383385161035776                    NaN                  NaN
# 801   772193107915964416                    NaN                  NaN
# 1002  747816857231626240                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2349  666049248165822465                    NaN                  NaN
# 2350  666044226329800704                    NaN                  NaN
# 2352  666029285002620928                    NaN                  NaN
# 2353  666020888022790149                    NaN                  NaN
# 2354                 NaN                    NaN                  NaN
#
#                       timestamp  \
# 56    2017-07-02 15:32:16 +0000
# 649   2016-10-31 02:17:31 +0000
# 759   2016-09-21 00:53:04 +0000
# 801   2016-09-04 23:46:12 +0000
# 1002  2016-06-28 20:14:22 +0000
# ...                         ...
# 2349  2015-11-16 00:35:11 +0000
# 2350  2015-11-16 00:30:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
#
#                                                  source  \
# 56    <a href="http://twitter.com/download/iphone" r...
# 649   <a href="http://twitter.com/download/iphone" r...
# 759   <a href="http://twitter.com/download/iphone" r...
# 801   <a href="http://twitter.com/download/iphone" r...
# 1002  <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2349  <a href="http://twitter.com/download/iphone" r...
# 2350  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 56    Here is a pupper approaching maximum borkdrive...                  NaN
# 649   Here is a perfect example of someone who has t...                  NaN
# 759   RT @dog_rates: This is an East African Chalupa...         7.030419e+17
# 801   Guys this is getting so out of hand. We only r...                  NaN
# 1002  This is a mighty rare blue-tailed hammer sherk...                  NaN
# ...                                                 ...                  ...
# 2349  This is an odd dog. Hard on the outside but lo...                  NaN
# 2350  This is a truly beautiful English Wilson Staff...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 56                         NaN                        NaN
# 649                        NaN                        NaN
# 759               4.196984e+09  2016-02-26 02:20:37 +0000
# 801                        NaN                        NaN
# 1002                       NaN                        NaN
# ...                        ...                        ...
# 2349                       NaN                        NaN
# 2350                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 56    https://twitter.com/dog_rates/status/881536004...                14
# 649   https://twitter.com/dog_rates/status/792913359...                13
# 759   https://twitter.com/dog_rates/status/703041949...                10
# 801   https://twitter.com/dog_rates/status/772581559...                10
# 1002  https://twitter.com/dog_rates/status/747885874...                 8
# ...                                                 ...               ...
# 2349  https://twitter.com/dog_rates/status/666051853...                 2
# 2350  https://twitter.com/dog_rates/status/666050758...                10
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
#
#       rating_denominator dog_name dog_stage
# 56                    10        a    pupper
# 649                   10        a
# 759                   10       an
# 801                   10        a
# 1002                  10        a
# ...                  ...      ...       ...
# 2349                  10       an
# 2350                  10        a
# 2352                  10        a
# 2353                  10        a
# 2354                  10        a
#
# [70 rows x 14 columns]

# %% [markdown]
# #### Define
# - Replace the the missrepresented dog names ie ('a', 'none', 'an' and 'the') with NaN.
#
#
#
# #### Clean: Code 8

# %%
misspelt_names = ['a', 'none', 'an', 'the']
for phrase in misspelt_names:
    twitter_archive_df_clean.dog_name.replace( phrase , np.NaN, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666033412701032449                    NaN                  NaN
# 2352  666029285002620928                    NaN                  NaN
# 2353  666020888022790149                    NaN                  NaN
# 2354                 NaN                    NaN                  NaN
# 2355                 NaN                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  dog_name dog_stage
# 0                     10   Phineas
# 1                     10     Tilly
# 2                     10    Archie
# 3                     10     Darla
# 4                     10  Franklin
# ...                  ...       ...       ...
# 2351                  10       NaN
# 2352                  10       NaN
# 2353                  10       NaN
# 2354                  10       NaN
# 2355                  10       NaN
#
# [2356 rows x 14 columns]

# %% [markdown]
# ### Unnecessary data in columns ("in_reply_to_status_id", "in_reply_to_user_id", "timestamp", "retweeted_status_id", "retweeted_status_user_id" and "retweeted_status_timestamp" columns) in `twitter_archive` dataset
# #### Define
# - Drop the unwanted columns in the twitter archive dataset i.e ("in_reply_to_status_id", "in_reply_to_user_id", "timestamp", "retweeted_status_id", "retweeted_status_user_id" and "retweeted_status_timestamp" columns)
#
#
#
# #### Clean: Code 9

# %%
#Drop rows with  invalid data that does not have dog breeds(p1=false) and and remain with rows with only dog breeds(p1=True)
twitter_archive_df_clean.drop(['in_reply_to_status_id','in_reply_to_user_id','timestamp','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp', 'expanded_urls'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_df_clean
# Out:
#                 tweet_id                                             source  \
# 0     892420643555336193  <a href="http://twitter.com/download/iphone" r...
# 1     892177421306343426  <a href="http://twitter.com/download/iphone" r...
# 2     891815181378084864  <a href="http://twitter.com/download/iphone" r...
# 3     891689557279858688  <a href="http://twitter.com/download/iphone" r...
# 4     891327558926688256  <a href="http://twitter.com/download/iphone" r...
# ...                  ...                                                ...
# 2351  666033412701032449  <a href="http://twitter.com/download/iphone" r...
# 2352  666029285002620928  <a href="http://twitter.com/download/iphone" r...
# 2353  666020888022790149  <a href="http://twitter.com/download/iphone" r...
# 2354                 NaN  <a href="http://twitter.com/download/iphone" r...
# 2355                 NaN  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 0     This is Phineas. He's a mystical boy. Only eve...                13
# 1     This is Tilly. She's just checking pup on you....                13
# 2     This is Archie. He is a rare Norwegian Pouncin...                12
# 3     This is Darla. She commenced a snooze mid meal...                13
# 4     This is Franklin. He would like you to stop ca...                12
# ...                                                 ...               ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                 5
# 2352  This is a purebred Piers Morgan. Loves to Netf...                 6
# 2353  Here is a very happy pup. Big fan of well-main...                 9
# 2354  This is a western brown Mitsubishi terrier. Up...                 7
# 2355  Here we have a Japanese Irish Setter. Lost eye...                 8
#
#       rating_denominator  dog_name dog_stage
# 0                     10   Phineas
# 1                     10     Tilly
# 2                     10    Archie
# 3                     10     Darla
# 4                     10  Franklin
# ...                  ...       ...       ...
# 2351                  10       NaN
# 2352                  10       NaN
# 2353                  10       NaN
# 2354                  10       NaN
# 2355                  10       NaN
#
# [2356 rows x 7 columns]

# %% [markdown]
# ### Some columns have multiple values instead of one in `twitter_archive_df_clean` dataset
# #### Define
# - Split the multiple values in the column of dog stage to have one value for each cell in the column.

# %%
#Checking the unique values to the the multiple values in one column.
twitter_archive_df_clean.dog_stage.unique()
# Out:
# array(['', 'doggo', 'puppo', 'pupper', 'floofer', 'doggo,puppo',
#        'doggo,floofer', 'doggo,pupper'], dtype=object)

# %% [markdown]
# #### Clean: Code 10

# %%
# assign data with one value in the "dog_stage" coumn to df3
x=['', 'doggo', 'puppo', 'pupper', 'floofer']
df3=twitter_archive_df_clean[twitter_archive_df_clean.dog_stage.isin(x)]

# %%
# assign data with two values in the "dog_stage" coumn to df1
x=['doggo,puppo','doggo,floofer', 'doggo,pupper']
df1=twitter_archive_df_clean[twitter_archive_df_clean.dog_stage.isin(x)]

# %%
#Split the dog staged combined in one cell
df1[['first_dog_stage','second_dog_stage']]=df1['dog_stage'].str.split(',', expand=True);
#Drop 'dog_stage' column
df1.drop(['dog_stage'], axis=1, inplace=True);

# %% [markdown]
# #### Test

# %%
df1
# Out:
#                 tweet_id                                             source  \
# 191   855818117272018944  <a href="http://twitter.com/download/iphone" r...
# 200   853760880890318849  <a href="http://twitter.com/download/iphone" r...
# 460   817536400337801217  <a href="http://twitter.com/download/iphone" r...
# 531   808001312164028416  <a href="http://twitter.com/download/iphone" r...
# 565   802247111496568832  <a href="http://twitter.com/download/iphone" r...
# 575   800859414831898624  <a href="http://twitter.com/download/iphone" r...
# 705   785533386513321988  <a href="http://twitter.com/download/iphone" r...
# 733   781251288990355457  <a href="http://vine.co" rel="nofollow">Vine -...
# 778   775842724423557120  <a href="http://twitter.com/download/iphone" r...
# 822   769940425801170949  <a href="http://twitter.com/download/iphone" r...
# 889   759557299618865152  <a href="http://twitter.com/download/iphone" r...
# 956   751456908746354688  <a href="http://twitter.com/download/iphone" r...
# 1063  740711788199743490  <a href="http://twitter.com/download/iphone" r...
# 1113  732726085725589504  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 191   Here's a puppo participating in the #ScienceMa...                13
# 200   At first I thought this was a shy doggo, but i...                11
# 460   This is Dido. She's playing the lead role in "...                13
# 531   Here we have Burke (pupper) and Dexter (doggo)...                12
# 565   Like doggo, like pupper version 2. Both 11/10 ...                11
# 575   This is Bones. He's being haunted by another d...                12
# 705   This is Pinot. He's a sophisticated doggo. You...                10
# 733   Pupper butt 1, Doggo 0. Both 12/10 https://t.c...                12
# 778   RT @dog_rates: Like father (doggo), like son (...                12
# 822   RT @dog_rates: This is just downright precious...                12
# 889   Meet Maggie &amp; Lila. Maggie is the doggo, L...                12
# 956   Please stop sending it pictures that don't eve...                 5
# 1063  This is just downright precious af. 12/10 for ...                12
# 1113  Like father (doggo), like son (pupper). Both 1...                12
#
#       rating_denominator dog_name first_dog_stage second_dog_stage
# 191                   10      NaN           doggo            puppo
# 200                   10      NaN           doggo          floofer
# 460                   10     Dido           doggo           pupper
# 531                   10      NaN           doggo           pupper
# 565                   10      NaN           doggo           pupper
# 575                   10    Bones           doggo           pupper
# 705                   10    Pinot           doggo           pupper
# 733                   10      NaN           doggo           pupper
# 778                   10      NaN           doggo           pupper
# 822                   10     just           doggo           pupper
# 889                   10   Maggie           doggo           pupper
# 956                   10      NaN           doggo           pupper
# 1063                  10     just           doggo           pupper
# 1113                  10      NaN           doggo           pupper

# %%
#Melt the 2 newly (first_dog_stage and second_dog_stage) formed column into one (dog_stage)
df2=df1.melt(id_vars = ['tweet_id','source','text_tweeted','rating_numerator','rating_denominator','dog_name'],
                               value_vars = ['first_dog_stage','second_dog_stage'],
                               var_name = 'identifier',
                               value_name = 'dog_stage')

# %%
#Drop 'identifier' column after melting the 2 dcolumns
df2.drop(['identifier'], axis=1, inplace=True);

# %%
#Merge df2 and df3
df_twitter_archive_df_clean=pd.concat([df2,df3])

# %% [markdown]
# #### Test

# %%
df_twitter_archive_df_clean
# Out:
#                 tweet_id                                             source  \
# 0     855818117272018944  <a href="http://twitter.com/download/iphone" r...
# 1     853760880890318849  <a href="http://twitter.com/download/iphone" r...
# 2     817536400337801217  <a href="http://twitter.com/download/iphone" r...
# 3     808001312164028416  <a href="http://twitter.com/download/iphone" r...
# 4     802247111496568832  <a href="http://twitter.com/download/iphone" r...
# ...                  ...                                                ...
# 2351  666033412701032449  <a href="http://twitter.com/download/iphone" r...
# 2352  666029285002620928  <a href="http://twitter.com/download/iphone" r...
# 2353  666020888022790149  <a href="http://twitter.com/download/iphone" r...
# 2354                 NaN  <a href="http://twitter.com/download/iphone" r...
# 2355                 NaN  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 0     Here's a puppo participating in the #ScienceMa...                13
# 1     At first I thought this was a shy doggo, but i...                11
# 2     This is Dido. She's playing the lead role in "...                13
# 3     Here we have Burke (pupper) and Dexter (doggo)...                12
# 4     Like doggo, like pupper version 2. Both 11/10 ...                11
# ...                                                 ...               ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                 5
# 2352  This is a purebred Piers Morgan. Loves to Netf...                 6
# 2353  Here is a very happy pup. Big fan of well-main...                 9
# 2354  This is a western brown Mitsubishi terrier. Up...                 7
# 2355  Here we have a Japanese Irish Setter. Lost eye...                 8
#
#       rating_denominator dog_name dog_stage
# 0                     10      NaN     doggo
# 1                     10      NaN     doggo
# 2                     10     Dido     doggo
# 3                     10      NaN     doggo
# 4                     10      NaN     doggo
# ...                  ...      ...       ...
# 2351                  10      NaN
# 2352                  10      NaN
# 2353                  10      NaN
# 2354                  10      NaN
# 2355                  10      NaN
#
# [2370 rows x 7 columns]

# %%
#Checking to confirm "dog_stage" column has only 1 entry in every cell
df_twitter_archive_df_clean.dog_stage.unique()
# Out:
# array(['doggo', 'puppo', 'floofer', 'pupper', ''], dtype=object)

# %% [markdown]
# ### each variable is not in its column and each observation not in its row.
# #### Define
# - Combine relating columns in the image_predictions_df_clean dataset ie [p1,p2,p3]-1st column, [p1_conf,p2_conf,p3_con1]-2nd column and [p1_dog,p2_dog,p3_dog]-3rd columns respectively.
#
#
#
# #### Clean: Code 11

# %%
img_prediction1=image_predictions_df_clean.melt(id_vars = ['tweet_id','jpg_url', 'img_num'],
                               value_vars = ['p1','p2','p3'],
                               var_name = 'Predictions',
                               value_name = 'dog_breeds')

img_prediction2=image_predictions_df_clean.melt(id_vars = ['tweet_id','jpg_url', 'img_num'],
                               value_vars = ['p1_dog','p2_dog','p3_dog'],
                               var_name = 'Predictions_count',
                               value_name = 'outcome')
#Merge the 2 datasets
df_clean=pd.merge(img_prediction1,img_prediction2)
image_preds_df_clean=df_clean.drop(index=df_clean[df_clean['outcome']==False].index)

# %%
image_preds_df_clean=df_clean.drop(index=df_clean[df_clean['outcome']==False].index)

# %% [markdown]
# #### Test

# %%
image_preds_df_clean
# Out:
#                  tweet_id                                          jpg_url  \
# 0      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 3      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 4      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# ...                   ...                                              ...
# 18661  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18662  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18663  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18664  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18665  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#        img_num Predictions              dog_breeds Predictions_count  outcome
# 0            1          p1  welsh_springer_spaniel            p1_dog     True
# 1            1          p1  welsh_springer_spaniel            p2_dog     True
# 2            1          p1  welsh_springer_spaniel            p3_dog     True
# 3            1          p2                  collie            p1_dog     True
# 4            1          p2                  collie            p2_dog     True
# ...        ...         ...                     ...               ...      ...
# 18661        1          p2                pekinese            p2_dog     True
# 18662        1          p2                pekinese            p3_dog     True
# 18663        1          p3                papillon            p1_dog     True
# 18664        1          p3                papillon            p2_dog     True
# 18665        1          p3                papillon            p3_dog     True
#
# [13752 rows x 7 columns]

# %%
image_preds_df_clean['tweet_id'].drop_duplicates()
# Out:
# 0        892420643555336193
# 9        892177421306343426
# 18       891815181378084864
# 27       891689557279858688
# 36       891327558926688256
#                 ...
# 18621    671115716440031232
# 18630    671109016219725825
# 18640    670995969505435648
# 18648    670842764863651840
# 18657    670840546554966016
# Name: tweet_id, Length: 1751, dtype: object

# %%
#Drop rows with non-dog beed enteries (outcome column=False)
image_preds_df_clean=image_preds_df_clean.drop(index=image_preds_df_clean[image_preds_df_clean['outcome']==False].index)
image_preds_df_clean
# Out:
#                  tweet_id                                          jpg_url  \
# 0      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 3      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 4      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# ...                   ...                                              ...
# 18661  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18662  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18663  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18664  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 18665  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#        img_num Predictions              dog_breeds Predictions_count  outcome
# 0            1          p1  welsh_springer_spaniel            p1_dog     True
# 1            1          p1  welsh_springer_spaniel            p2_dog     True
# 2            1          p1  welsh_springer_spaniel            p3_dog     True
# 3            1          p2                  collie            p1_dog     True
# 4            1          p2                  collie            p2_dog     True
# ...        ...         ...                     ...               ...      ...
# 18661        1          p2                pekinese            p2_dog     True
# 18662        1          p2                pekinese            p3_dog     True
# 18663        1          p3                papillon            p1_dog     True
# 18664        1          p3                papillon            p2_dog     True
# 18665        1          p3                papillon            p3_dog     True
#
# [13752 rows x 7 columns]

# %%
#Drop duplicated rows in the new dataset
image_preds_df_clean.drop_duplicates(subset='tweet_id', keep='first', inplace=True)
#Delete unnecessary columns that we will not use for analysis
image_preds_df_clean.drop(['img_num', 'Predictions','outcome', 'Predictions_count'], axis=1, inplace=True)

# %%
image_preds_df_clean
# Out:
#                  tweet_id                                          jpg_url  \
# 0      892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 9      892177421306343426  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 18     891815181378084864  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 27     891689557279858688  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 36     891327558926688256  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                   ...                                              ...
# 18621  671115716440031232  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 18630  671109016219725825  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 18640  670995969505435648  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 18648  670842764863651840  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 18657  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                      dog_breeds
# 0        welsh_springer_spaniel
# 9                       redbone
# 18              german_shepherd
# 27          rhodesian_ridgeback
# 36           miniature_pinscher
# ...                         ...
# 18621  chesapeake_bay_retriever
# 18630                    basset
# 18640               paper_towel
# 18648                 chihuahua
# 18657                 chihuahua
#
# [1751 rows x 3 columns]

# %% [markdown]
# # : Data storage, (EDA) and Visualizations.
# This is the stage where one creates insights uncovers the underlying structures, extract variables, detect outliers and test assumptions, develop models and  determine optimal factors in a dataset.

# %% [markdown]
# ## `Merge all the 3 datasets`
# - a)image_preds_df_clean
# - b)df_twitter_archive_df_clean
# - c)tweets_df_clean

# %%
df_twitter_archive_df_clean
# Out:
#                 tweet_id                                             source  \
# 0     855818117272018944  <a href="http://twitter.com/download/iphone" r...
# 1     853760880890318849  <a href="http://twitter.com/download/iphone" r...
# 2     817536400337801217  <a href="http://twitter.com/download/iphone" r...
# 3     808001312164028416  <a href="http://twitter.com/download/iphone" r...
# 4     802247111496568832  <a href="http://twitter.com/download/iphone" r...
# ...                  ...                                                ...
# 2351  666033412701032449  <a href="http://twitter.com/download/iphone" r...
# 2352  666029285002620928  <a href="http://twitter.com/download/iphone" r...
# 2353  666020888022790149  <a href="http://twitter.com/download/iphone" r...
# 2354                 NaN  <a href="http://twitter.com/download/iphone" r...
# 2355                 NaN  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 0     Here's a puppo participating in the #ScienceMa...                13
# 1     At first I thought this was a shy doggo, but i...                11
# 2     This is Dido. She's playing the lead role in "...                13
# 3     Here we have Burke (pupper) and Dexter (doggo)...                12
# 4     Like doggo, like pupper version 2. Both 11/10 ...                11
# ...                                                 ...               ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                 5
# 2352  This is a purebred Piers Morgan. Loves to Netf...                 6
# 2353  Here is a very happy pup. Big fan of well-main...                 9
# 2354  This is a western brown Mitsubishi terrier. Up...                 7
# 2355  Here we have a Japanese Irish Setter. Lost eye...                 8
#
#       rating_denominator dog_name dog_stage
# 0                     10      NaN     doggo
# 1                     10      NaN     doggo
# 2                     10     Dido     doggo
# 3                     10      NaN     doggo
# 4                     10      NaN     doggo
# ...                  ...      ...       ...
# 2351                  10      NaN
# 2352                  10      NaN
# 2353                  10      NaN
# 2354                  10      NaN
# 2355                  10      NaN
#
# [2370 rows x 7 columns]

# %%
#1st merge: merge twitter_archive_df_clean to mage_preds_df_clean
first_merge_df=image_preds_df_clean.merge(df_twitter_archive_df_clean,left_on='tweet_id', right_on='tweet_id', how='left')
#2nd merge: merge tweets_df_clean to first_merge_dfmerge_df=image_preds_df_clean.merge(twitter_archive_df_clean,left_on='tweet_id', right_on='tweet_id', how='left')
merged_df = first_merge_df.merge(tweets_df_clean,left_on='tweet_id', right_on='tweet_id', how='left')

# %%
merged_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     892177421306343426  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     891815181378084864  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     891689557279858688  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     891327558926688256  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 1758  671115716440031232  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 1759  671109016219725825  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 1760  670995969505435648  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 1761  670842764863651840  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 1762  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                     dog_breeds  \
# 0       welsh_springer_spaniel
# 1                      redbone
# 2              german_shepherd
# 3          rhodesian_ridgeback
# 4           miniature_pinscher
# ...                        ...
# 1758  chesapeake_bay_retriever
# 1759                    basset
# 1760               paper_towel
# 1761                 chihuahua
# 1762                 chihuahua
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 1758  <a href="http://twitter.com/download/iphone" r...
# 1759  <a href="http://twitter.com/download/iphone" r...
# 1760  <a href="http://twitter.com/download/iphone" r...
# 1761  <a href="http://twitter.com/download/iphone" r...
# 1762  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 0     This is Phineas. He's a mystical boy. Only eve...                13
# 1     This is Tilly. She's just checking pup on you....                13
# 2     This is Archie. He is a rare Norwegian Pouncin...                12
# 3     This is Darla. She commenced a snooze mid meal...                13
# 4     This is Franklin. He would like you to stop ca...                12
# ...                                                 ...               ...
# 1758  Say hello to Clarence. He's a western Alkaline...                 8
# 1759  Two miniature golden retrievers here. Webbed p...                 4
# 1760  Meet Phred. He isn't steering, looking at the ...                 6
# 1761  This is Toby. He asked for chocolate cake for ...                 8
# 1762  Yea I can't handle this job anymore your dogs ...                12
#
#       rating_denominator  dog_name dog_stage  retweet_count  favorite_count
# 0                     10   Phineas                     8853           39467
# 1                     10     Tilly                     6514           33819
# 2                     10    Archie                     4328           25461
# 3                     10     Darla                     8964           42908
# 4                     10  Franklin                     9774           41048
# ...                  ...       ...       ...            ...             ...
# 1758                  10  Clarence                      842            1436
# 1759                  10       NaN                      478            1225
# 1760                  10     Phred                      317            1175
# 1761                  10      Toby                     4324            7989
# 1762                  10       NaN                      213             634
#
# [1763 rows x 11 columns]

# %%
merged_df.shape
# Out:
# (1763, 11)

# %%
#Listing rows with data that is not dog breed
x=['comic_book',"jack-o'-lantern",'ox']
df1=merged_df[merged_df.dog_breeds.isin(x)]

# %%
df1
# Out:
#                 tweet_id                                            jpg_url  \
# 18    887473957103951883    https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 113   863471782782697472    https://pbs.twimg.com/media/CUdvambWoAA007z.jpg
# 185   846874817362120707    https://pbs.twimg.com/media/CU3cSG8W4AIAePH.jpg
# 312   822872901745569793    https://pbs.twimg.com/media/CVo-JuMWwAAet6F.jpg
# 846   744234799360020481  https://pbs.twimg.com/tweet_video_thumb/CeGGkW...
# 1295  689154315265683456    https://pbs.twimg.com/media/CwDjoH3WAAIniIs.jpg
#
#            dog_breeds                                             source  \
# 18                 ox  <a href="http://twitter.com/download/iphone" r...
# 113                ox  <a href="http://twitter.com/download/iphone" r...
# 185   jack-o'-lantern  <a href="http://twitter.com/download/iphone" r...
# 312   jack-o'-lantern  <a href="http://twitter.com/download/iphone" r...
# 846        comic_book  <a href="http://twitter.com/download/iphone" r...
# 1295  jack-o'-lantern  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 18    I've yet to rate a Venezuelan Hover Wiener. Th...                14
# 113   This is Neptune. He's a backpup vocalist for t...                13
# 185   Unbelievable... We. Only. Rate. Dogs. Please s...                11
# 312   This is Albus. He's soaked as h*ck. Seems to h...                12
# 846   This is Harvey. He's stealthy af. 10/10 would ...                10
# 1295  Meet Lucky. He was showing his friends an extr...                10
#
#       rating_denominator dog_name dog_stage  retweet_count  favorite_count
# 18                    10     such                    18781           69871
# 113                   10  Neptune                     2687               0
# 185                   10      NaN                     4404           21685
# 312                   10    Albus                    48265          132810
# 846                   10   Harvey                    79515          131075
# 1295                  10    Lucky                     1128            3348

# %%
#Deleting rows with data that is not dog breed
merged_df.drop([18,113,185,312,846,1295], axis=0, inplace=True);

# %%
merged_df.shape
# Out:
# (1757, 11)

# %% [markdown]
# ## Iteration
# The cleaning precess is an iterable process and most oftenly one will find themselves making correcrion to the cleaned data set or even clean the resulting clean datasets after doing the merging.

# %% [markdown]
# #### Define
# - Create a copy of the new merged dataFrame and name it `new_merege_df`
#
# #### Code

# %%
new_merge_df = merged_df.copy()

# %%
new_merge_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     892177421306343426  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     891815181378084864  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     891689557279858688  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     891327558926688256  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 1758  671115716440031232  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 1759  671109016219725825  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 1760  670995969505435648  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 1761  670842764863651840  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 1762  670840546554966016  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                     dog_breeds  \
# 0       welsh_springer_spaniel
# 1                      redbone
# 2              german_shepherd
# 3          rhodesian_ridgeback
# 4           miniature_pinscher
# ...                        ...
# 1758  chesapeake_bay_retriever
# 1759                    basset
# 1760               paper_towel
# 1761                 chihuahua
# 1762                 chihuahua
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 1758  <a href="http://twitter.com/download/iphone" r...
# 1759  <a href="http://twitter.com/download/iphone" r...
# 1760  <a href="http://twitter.com/download/iphone" r...
# 1761  <a href="http://twitter.com/download/iphone" r...
# 1762  <a href="http://twitter.com/download/iphone" r...
#
#                                            text_tweeted  rating_numerator  \
# 0     This is Phineas. He's a mystical boy. Only eve...                13
# 1     This is Tilly. She's just checking pup on you....                13
# 2     This is Archie. He is a rare Norwegian Pouncin...                12
# 3     This is Darla. She commenced a snooze mid meal...                13
# 4     This is Franklin. He would like you to stop ca...                12
# ...                                                 ...               ...
# 1758  Say hello to Clarence. He's a western Alkaline...                 8
# 1759  Two miniature golden retrievers here. Webbed p...                 4
# 1760  Meet Phred. He isn't steering, looking at the ...                 6
# 1761  This is Toby. He asked for chocolate cake for ...                 8
# 1762  Yea I can't handle this job anymore your dogs ...                12
#
#       rating_denominator  dog_name dog_stage  retweet_count  favorite_count
# 0                     10   Phineas                     8853           39467
# 1                     10     Tilly                     6514           33819
# 2                     10    Archie                     4328           25461
# 3                     10     Darla                     8964           42908
# 4                     10  Franklin                     9774           41048
# ...                  ...       ...       ...            ...             ...
# 1758                  10  Clarence                      842            1436
# 1759                  10       NaN                      478            1225
# 1760                  10     Phred                      317            1175
# 1761                  10      Toby                     4324            7989
# 1762                  10       NaN                      213             634
#
# [1757 rows x 11 columns]

# %%
new_merge_df.shape
# Out:
# (1757, 11)

# %%
new_merge_df.dog_name.value_counts()
# Out:
# Cooper     11
# Lucy       10
# Charlie    10
# Oliver     10
# Penny       8
#            ..
# Dixie       1
# Fizz        1
# Davey       1
# Willem      1
# Holly       1
# Name: dog_name, Length: 765, dtype: int64

# %% [markdown]
# #### Define
# - Drop clumns 'jpg_url', 'source' and 'text_tweeted' and rename the new data with less statment for earsier analysis and visualization, name it 'new_merege_df'
#
# #### Code

# %%
new_merge_df.drop(['jpg_url', 'source', 'text_tweeted'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
new_merge_df
# Out:
#                 tweet_id                dog_breeds  rating_numerator  \
# 0     892420643555336193    welsh_springer_spaniel                13
# 1     892177421306343426                   redbone                13
# 2     891815181378084864           german_shepherd                12
# 3     891689557279858688       rhodesian_ridgeback                13
# 4     891327558926688256        miniature_pinscher                12
# ...                  ...                       ...               ...
# 1758  671115716440031232  chesapeake_bay_retriever                 8
# 1759  671109016219725825                    basset                 4
# 1760  670995969505435648               paper_towel                 6
# 1761  670842764863651840                 chihuahua                 8
# 1762  670840546554966016                 chihuahua                12
#
#       rating_denominator  dog_name dog_stage  retweet_count  favorite_count
# 0                     10   Phineas                     8853           39467
# 1                     10     Tilly                     6514           33819
# 2                     10    Archie                     4328           25461
# 3                     10     Darla                     8964           42908
# 4                     10  Franklin                     9774           41048
# ...                  ...       ...       ...            ...             ...
# 1758                  10  Clarence                      842            1436
# 1759                  10       NaN                      478            1225
# 1760                  10     Phred                      317            1175
# 1761                  10      Toby                     4324            7989
# 1762                  10       NaN                      213             634
#
# [1757 rows x 8 columns]

# %%
new_merge_df[new_merge_df['rating_numerator']>12]
# Out:
#                 tweet_id               dog_breeds  rating_numerator  \
# 0     892420643555336193   welsh_springer_spaniel                13
# 1     892177421306343426                  redbone                13
# 3     891689557279858688      rhodesian_ridgeback                13
# 5     891087950875897856     bernese_mountain_dog                13
# 6     890729181411237888                     chow                13
# ...                  ...                      ...               ...
# 1617  674307341513269249  black-and-tan_coonhound                13
# 1650  673656262056419329               eskimo_dog                13
# 1721  671763349865160704               eskimo_dog                13
# 1727  671550332464455680                 pembroke                13
# 1728  671547767500775424                      pug                13
#
#       rating_denominator   dog_name dog_stage  retweet_count  favorite_count
# 0                     10    Phineas                     8853           39467
# 1                     10      Tilly                     6514           33819
# 3                     10      Darla                     8964           42908
# 5                     10        NaN                     3261           20562
# 6                     10        NaN                    16716           56848
# ...                  ...        ...       ...            ...             ...
# 1617                  10        NaN                     7641           12129
# 1650                  10  Shnuggles                      265             769
# 1721                  10      space                      999            1788
# 1727                  10        NaN                      229             967
# 1728                  10        NaN                      658            1444
#
# [333 rows x 8 columns]

# %%
new_merge_df.shape
# Out:
# (1757, 8)

# %% [markdown]
# ## :Data storage

# %%
#Storing the new cleaned merged datasets as 'twitter_archive_master.csv'.
new_merge_df.to_csv('twitter_archive_master.csv' ,index = False)

# %% [markdown]
# ## :Visualization

# %% [markdown]
# ### Questions to be addresses in the new merged data, to provide insights in the copy of the merged data frames  `new_merge_df`
# 1. What type of dog stage receive most likes (favorite_count) when posted.?
# 2. Which dog stage received the most retweeted?
# 3. Which dog stages is the most popularly posted?
# 4. Identify dog breeds with the highest numerator ratings?
# 5. Which dog breeds are the most retweeted?
# 6. Determine the most popular breeds of dogs posted?
# 7. Determine the top popular dog names from the data?
# 8. Which dog breeds received most likes (favorite_count)?
# 9. Determine the most popular dog names posted from the data?
# 10. Which dog breeds received most likes (favorite_count)?
# 11. What is the relationship between favorite_count and retweet_count?

# %%
new_merge_df.describe()
# Out:
#        rating_numerator  rating_denominator  retweet_count  favorite_count
# count       1757.000000         1757.000000    1757.000000     1757.000000
# mean          13.731360           10.572567    3339.167900     8730.652248
# std           51.997389            7.668829    4964.949278    11174.560200
# min            0.000000            0.000000       2.000000        0.000000
# 25%           10.000000           10.000000     823.000000     2176.000000
# 50%           11.000000           10.000000    1722.000000     4228.000000
# 75%           12.000000           10.000000    3911.000000    11271.000000
# max         1776.000000          170.000000   56625.000000   107956.000000

# %%
#create functions for the graphs
def labler_fn(xaxis, yaxis, title):
    xaxis = plt.xlabel(xaxis)
    yaxis = plt.ylabel(yaxis)
    title = plt.title(title)
    
def bar(x, y, xaxis, yaxis, title):
    plt.bar(x, y,)
    labler_fn(xaxis, yaxis, title)
plt.show()

def hist(x, xaxis, yaxis, title):
    plt.hist(x)
    labler_fn(xaxis, yaxis, title)
plt.show()

a=['x','y','z']
def url(jpg_url):
    img_link = merged_df[merged_df.jpg_url == jpg_url]
    img_link = img_link.loc[:,a]
    return img_link

# %%
a=['dog_name','dog_stage','text_tweeted']
#Checking how many dog breeds we have.
new_merge_df['dog_stage'].unique()
# Out:
# array(['', 'doggo', 'puppo', 'floofer', 'pupper'], dtype=object)

# %% [markdown]
# #### Question 1:
# What type of dog stage receive most likes (favorite_count) when posted.

# %%
#plot a graph showing dog_stage with number of likes (favorite_count).
new_merge_df.groupby('dog_stage',).favorite_count.mean().plot(kind='bar')
plt.ylabel('favorite_count', fontsize = 16);
plt.xlabel('Dog stages', fontsize = 16)
plt.title('Relationship between dog stage and favorite_count', fontsize = 16);

# %%
url('https://pbs.twimg.com/media/Cj_P7rSUgAAYQbz.jpg')
# Out:
#     dog_name dog_stage                                       text_tweeted
# 977     Otis            This is Otis. Everybody look at Otis. 12/10 wo...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/Cj_P7rSUgAAYQbz.jpg)

# %%
url('https://pbs.twimg.com/media/CjQnclkVEAA4pnK.jpg')
# Out:
#     dog_name dog_stage                                       text_tweeted
# 961   Jangle            This is Jangle. She's addicted to broccoli. It...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CjQnclkVEAA4pnK.jpg)

# %% [markdown]
# From the above observation the analysis clearly shows that the doggo, puppo and fluffer are the most liked dog stages since they received the highest likes in the "WeRateDogs" twitter report, followed by pupper.The 1st bar shows dogs that were twitted without listing their dog stage.

# %% [markdown]
# #### Question 2:
# Which dog stage received the most retweet?

# %%
#plot a bar graph to comparing the number of retweets each dog stage received.
bar(new_merge_df.dog_stage, new_merge_df.retweet_count, 'Dog stage', 'Retweet count', 'Number of retweets on every dog stages')

# %%
url('https://pbs.twimg.com/media/CiyHLocU4AI2pJu.jpg')
# Out:
#      dog_name dog_stage                                       text_tweeted
# 952      Fred            This is Fred-Rick. He dabbles in parkour. The ...
# 1201      NaN            After reading the comments I may have overesti...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CiyHLocU4AI2pJu.jpg)

# %%
url('https://pbs.twimg.com/media/CotUFZEWcAA2Pku.jpg')
# Out:
#      dog_name dog_stage                                       text_tweeted
# 1121  Stanley            Meet Stanley. He's an inverted Uzbekistani wat...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CotUFZEWcAA2Pku.jpg)

# %% [markdown]
# The graph above depics that the most retweeted dog stage is pupper followed by doggo and then puppo. since the highest is a bar representing retweets for dogs whose stage was not defined.

# %% [markdown]
# #### Question 3:
# Which dog stages is the most tweeted?

# %%
#plot a pie chart showing the popular dog stages twisted.
new_merge_df.dog_stage.value_counts().plot(kind = 'pie', figsize = (10, 8));

# %%
url('https://pbs.twimg.com/media/CV1HztsWoAAuZwo.jpg')
# Out:
#      dog_name dog_stage                                       text_tweeted
# 345  Florence            This is Florence. He saw the same snap you sen...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CV1HztsWoAAuZwo.jpg)

# %%
url('https://pbs.twimg.com/media/DEAz_HHXsAA-p_z.jpg')
# Out:
#      dog_name dog_stage                                       text_tweeted
# 1720      NaN            Remarkable dog here. Walks on back legs really...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/DEAz_HHXsAA-p_z.jpg)

# %% [markdown]
# The pie chart shows the data on what dog stage is popularly posted on twitter, and from the observation pupper appears to be the most popular amonng the dogs that had their stage defined followed by doggo.

# %% [markdown]
# #### Question 4:
# Identify dog stage with the highest numerator ratings

# %%
#plot a graph showing dog_stage with Numerator_rating.
new_merge_df.groupby('dog_stage').rating_numerator.mean().plot(kind='bar', figsize = (8, 6))
plt.ylabel('Numerator_rating');
plt.title('Relationship between dog stage and rating', fontsize = 16);

# %%
url('https://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg')
# Out:
#      dog_name dog_stage                                       text_tweeted
# 1736      Jax            Meet Jax. He's in the middle of a serious conv...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg)

# %% [markdown]
# All dog stages have a rating above 10 which tends to agree with the statement 'unique rating system is a big part of the popularity of WeRateDogs'
# This indicates that every dog no matter what stage they are is a great a dog.

# %% [markdown]
# #### Question 5:
# Which dog breeds are the most retweeted?

# %%
a=['dog_name','dog_breeds','text_tweeted']

# %%
#this returns values with retweet_count above 30000
retweet_count_mean1 = new_merge_df[new_merge_df['retweet_count']>30000]
#Plot a bar graph showing the most retweeted dog breed.
retweet_count_mean1.groupby('dog_breeds').retweet_count.mean().plot(kind='bar', figsize = (8, 6))
plt.ylabel('retweet_count');
plt.title('Most retweeted dog breeds', fontsize = 16);

# %%
url('https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg')
# Out:
#      dog_name        dog_breeds  \
# 1749      NaN  golden_retriever
#
#                                            text_tweeted
# 1749  This pup holds the secrets of the universe in ...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg)

# %%
url('https://pbs.twimg.com/media/C4LMUf8WYAkWz4I.jpg')
# Out:
#      dog_name          dog_breeds  \
# 1509    Sandy  labrador_retriever
#
#                                            text_tweeted
# 1509  This is Sandy. He's sexually confused. Thinks ...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/C4LMUf8WYAkWz4I.jpg)

# %% [markdown]
# The above graphs provides us with an observation that the most retweeted posts had chihuahua followed by samoyed then golden retriever breeds.

# %% [markdown]
# #### Question 6:
# Determine the most popular breeds of dogs posted .

# %%
#this returns values with retweet_count above 20000
retweet_count_mean1 = new_merge_df[new_merge_df['retweet_count']>20000]
#plot a pie chart showing the popularity of dog breeds that appear on the highest retweets.
retweet_count_mean1.dog_breeds.value_counts().plot(kind = 'pie', figsize = (10, 8));

# %%
url('https://pbs.twimg.com/media/CX6_y6OU0AAl3v2.jpg')
# Out:
#     dog_name dog_breeds                                       text_tweeted
# 545    Moose  chihuahua  This is Moose. He's rather h*ckin dangerous (y...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CX6_y6OU0AAl3v2.jpg)

# %% [markdown]
# The graph above depics that the 3 most popular breeds of dogs posted on twitter are the labrader retriever, toy poodle, samoyed, staffordshire bull terrier, golden retriever and basset and chihuahua respectively. The popularity rate for other breeds seems to be almost at the same level.

# %% [markdown]
# #### Question 7:
# Which dog breeds received most likes (favorite_count).

# %%
#this returns values with retweet_count above 50000
favorite_count_mean1 = new_merge_df[new_merge_df['favorite_count']>50000]
#plot a bar graph to showing the most liked dog breeds (50000 likes).
bar(favorite_count_mean1.dog_breeds, favorite_count_mean1.favorite_count, 'Dog Breeds', 'Favorite count', 'Dog breeds that received more than 50000 likes')
plt.xticks(rotation=90);

# %%
url('https://pbs.twimg.com/media/CUrIK1DWoAAhECq.jpg')
# Out:
#     dog_name dog_breeds                                       text_tweeted
# 153      NaN  chihuahua  I HEARD HE TIED HIS OWN BOWTIE MARK AND HE JUS...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CUrIK1DWoAAhECq.jpg)

# %% [markdown]
# The visualization created in the above graphs shows the breeds of dogs that received most likes (above 50000). Toy poodle and standard poodle took the lead followed by labrador retriever then pekinese, golden retriever and great pyrenees.

# %% [markdown]
# #### Question 8:
# Determine the most popular dog names posted from the data.

# %%
#this returns values with favorite_count above 40000
favorite_count1 = new_merge_df[new_merge_df['favorite_count']>40000]
#plot a graph showing popular dog names.
favorite_count1.groupby('dog_name').favorite_count.mean().plot(kind='bar', figsize = (8, 6))
plt.ylabel('No. of likes received');
plt.title('Dog names that received the most likes', fontsize = 16);

# %%
url('https://pbs.twimg.com/media/CZiBcJhWQAATXNK.jpg')
# Out:
#     dog_name            dog_breeds  \
# 637      NaN  bernese_mountain_dog
#
#                                           text_tweeted
# 637  Guys this is getting so out of hand. We only r...

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CZiBcJhWQAATXNK.jpg)

# %% [markdown]
# ![title](https://pbs.twimg.com/media/CXXdJ7CVAAALu23.jpg)

# %% [markdown]
# The visualization from the above graph shows that the names of dogs that received highest number of likes when they were posted are, Bailey, Lili, Cody, Lennon, Reggie, Emmy....respectively.

# %% [markdown]
# #### Question 9:
# What is the relationship between favorite_count and retweet_count.

# %%
#Plot a graph showing relationship between retweet_count and favorite_count
sns.regplot(new_merge_df.favorite_count/10000,new_merge_df.retweet_count/10000)
plt.title('Relationship between retweet_count and favorite_count');

# %% [markdown]
# From the graph above, we can observe that there is a positive corelation between the number of likes a post will receive and if the post will be retweered.

# %% [markdown]
# # : Assumptions and conclusions

# %% [markdown]
# ## a) General Observations.
# The highest likes on dog stage was received by doggo, puppo and fluffer respectively.
# While the most retweeted was pupper doggo and puppo respectively.
#
# Hence Doggo seems to be the most popular dog stage  since it appears to rate among the top in the most liked and most retweeted in the twitter posts despite pupper being the most twitted.
#
# Analysis on dog breeds indicate that chihuahua was the most retweeted breed followed by golden retriever and then samoyed,
# While the most posted breeds on twitter are the labrader retriever, golden retriever, samoyed, staffordshire bull terrier and toy poodle respectively.
# Toy poodle and standard poodle are the most liked breeds followed by labrador retriever then pekinese, golden retriever and great pyrenees respectively.
#
# From this observation is safe to say the golden retriever is the most popular breed since it always find itself among the top for the most liked and and most retweeted breed.
#
# From the analysis we can tell that among the most posted dogs, there are names that are more recurrent and these famous dog names include Bailey, Lili, Cody, Lennon, Reggie, Emmy just to mention a few, bailey being the most posted.

# %% [markdown]
# ## c) Conclusion.

# %% [markdown]
# From the above analysis we can make the following conclusions;
# - The number of retweets tends to rise with the number of likes on a tweet.
# - Doggo is the most popular dog stage since it  ranks higherest for likes and retweets.
# - Golden retriever seems to be the most popular dog breeds since it always find a way to make it to top 5 of the list (likes  and retweets).
